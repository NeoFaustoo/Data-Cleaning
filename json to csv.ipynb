# %%
import pandas as pd
import json

# %%
with open('D:/Downloands/stock RNE formalité 20240903/stock_002243.json', "r", encoding="utf-8") as file:
    data = json.load(file)

# Normalize JSON
df = pd.json_normalize(data,sep='_')
df = df.head(2000)

# Save as CSV
df.to_csv("D:/Downloands/sample.csv", index=False)

# %%
df = pd.read_csv("D:/Downloands/sample.csv", encoding="utf-8", low_memory=False)

print(df.shape)
df.info
# Out:
# (2000, 572)
# <bound method DataFrame.info of                       updatedAt  nombreRepresentantsActifs  \
# 0     2024-02-24T20:15:23+01:00                          0
# 1     2024-05-19T12:06:01+02:00                          3
# 2     2024-05-19T12:06:02+02:00                          2
# 3     2024-05-19T12:06:03+02:00                          2
# 4     2024-07-11T04:12:24+02:00                          1
# ...                         ...                        ...
# 1995  2024-07-06T22:45:08+02:00                          0
# 1996  2024-07-06T22:45:08+02:00                          0
# 1997  2024-07-06T22:45:08+02:00                          0
# 1998  2024-07-06T22:45:10+02:00                          0
# 1999  2024-07-06T22:45:14+02:00                          0
#
#       nombreEtablissementsOuverts                        id      siren  \
# 0                               1  63ae75ace0e85a58e312729d  911583557
# ...
